# %%
from pyspark.sql import SparkSession
from v_time import timeit

import constants as c

spark = SparkSession.builder.appName("cat_info").getOrCreate()

# %% [markdown]
# # 1. Load data

# %%
sdf = timeit(spark.read.csv)(c.URI_CSV, header=True)
# Out:
# timeit: 'csv' in 3.60 s

# %% [markdown]
# <div class="alert alert-info" role="alert">
#     Spark is lazy. It won't do anything until you ask for something that will imply some action to the data. So read a csv it will only means read the schema
# </div>

# %%
sdf.show()
# Out:
# +--------------+------------+-------------+--------------------+--------------------+-------------+----------+---------+
# |            ID|CODI_ESTACIO|CODI_VARIABLE|        DATA_LECTURA|         DATA_EXTREM|VALOR_LECTURA|CODI_ESTAT|CODI_BASE|
# +--------------+------------+-------------+--------------------+--------------------+-------------+----------+---------+
# |WX422901150200|          WX|           42|29/01/2015 02:00:...|29/01/2015 02:00:...|          9.5|         V|       SH|
# |WX442901150200|          WX|           44|29/01/2015 02:00:...|29/01/2015 02:00:...|           49|         V|       SH|
# |WX462901150200|          WX|           46|29/01/2015 02:00:...|                null|          4.4|         V|       SH|
# |WX472901150200|          WX|           47|29/01/2015 02:00:...|                null|          258|         V|       SH|
# |WX562901150200|          WX|           56|29/01/2015 02:00:...|29/01/2015 02:00:...|          8.6|         V|       SH|
# ...

# %%
sdf.limit(5).toPandas()
# Out:
#                ID CODI_ESTACIO CODI_VARIABLE            DATA_LECTURA  \
# 0  WX422901150200           WX            42  29/01/2015 02:00:00 PM
# 1  WX442901150200           WX            44  29/01/2015 02:00:00 PM
# 2  WX462901150200           WX            46  29/01/2015 02:00:00 PM
# 3  WX472901150200           WX            47  29/01/2015 02:00:00 PM
# 4  WX562901150200           WX            56  29/01/2015 02:00:00 PM
#
#               DATA_EXTREM VALOR_LECTURA CODI_ESTAT CODI_BASE
# 0  29/01/2015 02:00:00 PM           9.5          V        SH
# 1  29/01/2015 02:00:00 PM            49          V        SH
# 2                    None           4.4          V        SH
# 3                    None           258          V        SH
# 4  29/01/2015 02:00:00 PM           8.6          V        SH

# %%
sdf = spark.createDataFrame(sdf.limit(5).toPandas())

# %%
sdf.count()
# Out:
# 5

# %%
import os

# %%
# Out:
# 'C:/PYTHON/villoro_posts/pyspark/tmp.delta'

# %%
sdf.write.format("csv").mode("overwrite").save("C:/PYTHON/villoro_posts/pyspark/tmp.delta")
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-27-e8debc2f862f> in <module>
# ----> 1 sdf.write.format("csv").mode("overwrite").save("C:/PYTHON/villoro_posts/pyspark/tmp.delta")
#
# c:\miniconda3\lib\site-packages\pyspark\sql\readwriter.py in save(self, path, format, mode, partitionBy, **options)
#     736             self._jwrite.save()
#     737         else:
# --> 738             self._jwrite.save(path)
#     739
#     740     @since(1.4)
#
# c:\miniconda3\lib\site-packages\py4j\java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# c:\miniconda3\lib\site-packages\pyspark\sql\utils.py in deco(*a, **kw)
# ...

# %%
sdf = timeit(spark.read.csv)(c.URI_VARS, header=True)
# Out:
# timeit: 'csv' in 0.33 s

# %%
sdf.toPandas()
# Out:
#    CODI_VARIABLE                                 NOM_VARIABLE UNITAT  \
# 0             72               Precipitació màxima en 1 minut     mm
# 1              3                      Humitat relativa màxima      %
# 2             30             Velocitat del vent a 10 m (esc.)    m/s
# 3             31                 Direcció de vent 10 m (m. 1)      °
# 4             32                                  Temperatura     °C
# 5             33                             Humitat relativa      %
# 6             34                          Pressió atmosfèrica    hPa
# 7             35                                 Precipitació     mm
# 8             36                     Irradiància solar global   W/m²
# 9             38                         Gruix de neu a terra     mm
# 10            40                           Temperatura màxima     °C
# 11            42                           Temperatura mínima     °C
# 12            44                      Humitat relativa mínima      %
# ...
